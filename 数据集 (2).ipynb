# %%
[
  {
    "input":"Automobile.xlsx中，volkswagen model 111与toyota corona hardtop的原产地分别是哪里",
    "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'Automobile.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nvolkswagen_origin = df.loc[df['name'] == 'volkswagen model 111', 'orign'].values[0]\ntoyota_origin = df.loc[df['name'] == 'toyota corona hardtop', 'orign'].values[0]\nprint(f"Volkswagen Model 111 的 'orign' 是：{volkswagen_origin}")\nprint(f"Toyota Corona Hardtop 的 'orign' 是：{toyota_origin}")"
  },
  {
  "input":"Automobile.xlsx中，马力最大的汽车是哪一辆",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'Automobile.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nmax_horsepower_car = df.loc[df['horsepower'].idxmax()]/nprint("马力最大的汽车是：", max_horsepower_row['name'])"
  },
  {
  "input":"Automobile.xlsx中，为所有汽车的重量做一个柱状统计图",
   "output":"!pip install pandas\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'Automobile.xls')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nplt.figure(figsize=(10, 6))\nplt.bar(data['name'], data['weight'])\nplt.xlabel('Car Names')\nplt.ylabel('Weight')\nplt.title('Car Weights')\nplt.xticks(rotation=90)\nplt.tight_layout()\nplt.show()"
  },
  {
  "input":"Automobile.xlsx中，计算每辆汽车马力和重量的比值，并将结果添加到最后一列",
   "output":""!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'Automobile.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf['hp_to_weight_ratio'] = df['horsepower'] / df['weight']\ndf.to_excel(file_path, index=False)"
  },
  {
  "input":"Automobile.xlsx中，绘制汽车不同气缸数的饼图",
   "output":""!pip install pandas\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'Automobile.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ncylinder_counts = data['cylinders'].value_counts()\nplt.figure(figsize=(8, 8))\nplt.pie(cylinder_counts, labels=cylinder_counts.index, autopct='%1.1f%%', startangle=140)\nplt.axis('equal')\nplt.title('汽车不同气缸数的分布')\nplt.show()"
  },
  {
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，进球最多的是来自哪个俱乐部的哪个球员,他一共进了多少球",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EPL_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nmax_goals = data['Goals'].max()\nplayer_info = data[data['Goals'] == max_goals][['Name', 'Clubs']]\nprint(f"在20-21赛季的英超联赛中，进球最多的是来自 {player_info['Clubs'].values[0]} 俱乐部的 {player_info['Name'].values[0]}，他共进了 {max_goals} 球。")"
  },
  {
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，将每个球员把握机会能力计算出来并添加到最后一列并找出把握机会能力最强的球员是谁"，
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EPL_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndata['Finishing Ability'] = data['Goals'] / data['xG']\ndata.to_excel('EPL_20_21_with_Finishing_Ability.xls', index=False)\nbest_player = data.loc[data['Finishing Ability'].idxmax()]\nprint(f"把握机会能力最强的球员是：{best_player['Name']}，把握机会能力为：{best_player['Finishing Ability']}")"
  },
  {
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，为Liverpool俱乐部的球员出场时间做一个柱状图"，
  "output":"!pip install pandas\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EP_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nliverpool_players = df[df['Clubs'] == 'Liverpool']\nplt.figure(figsize=(10, 6))\nplt.bar(liverpool_players['Name'], liverpool_players['Mins'], color='red')\nplt.xlabel('Player Name')\nplt.ylabel('Minutes Played')\nplt.title('Liverpool Players\' Minutes Played in EPL 20-21 Season')\nplt.xticks(rotation=90)\nplt.tight_layout()\nplt.show()"
  },
  {
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，为不同俱乐部的黄牌总数做一个折线图"，
  "output":"!pip install pandas\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EP_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nyellow_cards_by_club = data.groupby('Clubs')['Yellow_Cards'].sum().reset_index()\nplt.figure(figsize=(10, 6))\nplt.plot(yellow_cards_by_club['Clubs'], yellow_cards_by_club['Yellow_Cards'], marker='o', linestyle='-', color='b')\nplt.title('Yellow Cards by Club in EPL 20-21 Season')\nplt.xlabel('Clubs')\nplt.ylabel('Total Yellow Cards')\nplt.xticks(rotation=45)\nplt.tight_layout()\nplt.show()"
  },
  {
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，计算每个俱乐部的前锋进球数(前锋为FW,中场为MF，后卫为DF，守门员为GK，一个球员可能包含多个位置），并按照俱乐部的不同做成饼图",
  "output":"!pip install pandas\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EP_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nforward_goals = data[data['Position'].str.contains('FW', na=False)].groupby('Clubs')['Goals'].sum()\nplt.figure(figsize=(8, 8))\nforward_goals.plot(kind='pie', autopct='%1.1f%%', startangle=90)\nplt.title('Forward Goals by Club in EPL 20-21 Season')\nplt.ylabel('')\nplt.legend(title='Clubs', loc='upper right')\nplt.axis('equal')\nplt.show()"
  },
  {
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，哪个国家的球员攻击性最强（进球最多）",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EPL_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ngoals_by_nationality = df.groupby('Nationality')['Goals'].sum()\nmost_goals_nationality = goals_by_nationality.idxmax()\ntotal_goals = goals_by_nationality.max()\nprint(f"攻击性最强的国家是 {most_goals_nationality}，其总进球数为 {total_goals} 个")"
  },
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，请给出曼城球员凯尔沃克的进球助攻以及黄牌数据",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EPL_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ngoals = kyle_walker_data['Goals'].sum()\nassists = kyle_walker_data['Assists'].sum()\nyellow_cards = kyle_walker_data['Yellow Cards'].sum()\nprint(f"凯尔沃克的进球数：{goals}")\nprint(f"凯尔沃克的助攻数：{assists}")\nprint(f"凯尔沃克的黄牌数：{yellow_cards}")"
  },
  {
  "input":"songs_normalize.xlsx中，2000-2019年Spotify中流行度最高的歌曲是哪些歌手的那些歌曲，它们的发行年份是哪一年"，
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'songs_normalize.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nfiltered_df = df[(df['year'] >= 2000) & (df['year'] <= 2019)]\nmax_popularity_index = filtered_df['popularity'].idxmax()\nmost_popular_artist = filtered_df.loc[max_popularity_index, 'artist']\nmost_popular_song = filtered_df.loc[max_popularity_index, 'song']\nrelease_year = filtered_df.loc[max_popularity_index, 'year']\nprint(f"在{release_year}年，Spotify中流行度最高的歌曲是 {most_popular_artist} 的 {most_popular_song}")"
  },
  {
  "input":"songs_normalize.xlsx中，2000-2019年Spotify中可舞性排行前十的歌曲是哪些歌手演唱的什么歌曲，它们的发行年份是哪一年"，
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'songs_normalize.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nfiltered_df = df[(df['year'] >= 2000) & (df['year'] <= 2019)]\ntop_songs = filtered_df.sort_values(by='popularity', ascending=False).head(10)\nprint(top_songs[['artist', 'song', 'year']])"
  },
  {
  "input":"songs_normalize.xlsx中，2000-2019年Spotify中2002年的歌曲的平均响度是多少",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'songs_normalize.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf_2002 = df[df['year'] == 2002]\naverage_loudness_2002 = df_2002['loudness'].mean()\nprint(average_loudness_2002)"
  },
  {
  "input":"songs_normalize.xlsx中，2000-2019年Spotify中的歌曲按照器乐性排序并生成新的excel表格",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'songs_normalize.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf_filtered = df[(df['year'] >= 2000) & (df['year'] <= 2019)]\ndf_sorted = df_filtered.sort_values(by='instrumentalness')\ndf_sorted.to_excel('sorted_songs_2000_2019.xls', index=False)"
  },
  {
  "input":"songs_normalize.xlsx中，2000-2019年Spotify中出现次数最多的歌手是谁，出现了几次，分别在哪一年",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'songs_normalize.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nfiltered_df = df[(df['year'] >= 2000) & (df['year'] <= 2019)]\nartist_counts = filtered_df['artist'].value_counts()\nmost_frequent_artist = artist_counts.idxmax()\nfrequency = artist_counts.max()\nyears_most_frequent_artist = filtered_df.loc[filtered_df['artist'] == most_frequent_artist, 'year'].tolist()\nprint("最多出现的歌手是：", most_frequent_artist)\nprint("出现次数：", frequency)\n)print("出现年份：", years_most_frequent_artist)"
  },
  {
  "input":"songs_normalize.xlsx中，2000-2019年Spotify中的歌曲平均持续时间是多少",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'songs_normalize.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nfiltered_df = df[(df['year'] >= 2000) & (df['year'] <= 2019)]\naverage_duration = filtered_df['duration_ms'].mean()\nprint(average_duration)"
  },
  {
  "input":"songs_normalize.xlsx中，2000-2019年Spotify中的歌曲流行度最高的100首中的节奏的平均值是多少",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'songs_normalize.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nfiltered_df = df[(df['year'] >= 2000) & (df['year'] <= 2019)]\ntop_100_songs = filtered_df.nlargest(100, 'popularity')\naverage_tempo = top_100_songs['tempo'].mean()\nprint(average_tempo)"
  },
  {
  "input":"songs_normalize.xlsx中，按照2000-2019年Spotify中歌曲的积极性绘制热图",
  "output":""!pip install pandas\n!pip install xlrd\n!pip install seaborn\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport seaborn as sns\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'songs_normalize.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf_filtered = df[(df['year'] >= 2000) & (df['year'] <= 2019)]\nplt.figure(figsize=(12, 8))\nheatmap_data = filtered_df.pivot_table(values='valence', index='artist', columns='song', aggfunc='mean')\nsns.heatmap(heatmap_data, cmap='viridis', cbar_kws={'label': 'Valence'})\nplt.title('Valence of Songs on Spotify (2000-2019)')\nplt.show()"
  },
   {
   "input":"songs_normalize.xlsx中，2000-2019年Spotify中按照每一年的歌曲流行度平均值绘制折线图",
  "output":""!pip install pandas\n!pip install xlrd\n!pip install seaborn\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport seaborn as sns\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'songs_normalize.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ngrouped_data = df.groupby('year')['popularity'].mean()\nplt.plot(grouped_data.index, grouped_data.values, marker='o')\nplt.title('Average Spotify Song Popularity (2000-2019)')\nplt.xlabel('Year')\nplt.ylabel('Average Popularity')\nplt.grid(True)\nplt.show()"
  },
   {
   "input":"songs_normalize.xlsx中，2000-2019年Spotify中歌曲按照每一年歌曲能量总和绘制柱状图",
  "output":""!pip install pandas\n!pip install xlrd\n!pip install seaborn\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport seaborn as sns\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'songs_normalize.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf_filtered = df[(df['year'] >= 2000) & (df['year'] <= 2019)]\ngrouped_df = df_filtered.groupby(['year', 'artist'])['energy'].sum().reset_index()\nyearly_energy_sum = grouped_df.groupby('year')['energy'].sum()\nplt.bar(yearly_energy_sum.index, yearly_energy_sum.values, color='skyblue')\nplt.xlabel('Year')\nplt.ylabel('Total Energy of Songs')\nplt.title('Total Energy of Songs on Spotify (2000-2019)')\nplt.show()"
  },
  {
  "input":"songs_normalize.xlsx中，按照2000-2019年Spotify中歌曲效价在0.5以上的按照不同年份占据的数量绘制饼图",
  "output":""!pip install pandas\n!pip install xlrd\n!pip install seaborn\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport seaborn as sns\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'songs_normalize.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nfiltered_df = df[(df['valence'] > 0.5) & (df['year'] >= 2000) & (df['year'] <= 2019)]\nyearly_counts = filtered_df.groupby('year').size()\nplt.figure(figsize=(10, 6))\nplt.pie(yearly_counts, labels=yearly_counts.index, autopct='%1.1f%%', startangle=140)\nplt.title('Songs with Valence > 0.5 Distribution (2000-2019)')\nplt.show()"
  },
  {
  "input":"songs_normalize.xlsx中，请给出歌曲的调为2的按照响度划分的折线图",
  "output":""!pip install pandas\n!pip install xlrd\n!pip install seaborn\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport seaborn as sns\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'songs_normalize.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf_filtered = df[df['key'] == 2]\ndf_filtered_sorted = df_filtered.sort_values(by='loudness')\nplt.plot(df_filtered_sorted['loudness'], marker='o')\nplt.title('歌曲调为2的按照响度划分的折线图')\nplt.xlabel('歌曲')\nplt.ylabel('响度')\nplt.show()"
  },
  {
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，Liverpool队内所有球员预期进球总和是多少",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EPL_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nliverpool_data = df[df['Club'] == 'Liverpool']\nxG_sum = liverpool_data['xG'].sum()\nprint("Liverpool队内所有球员预期进球总和:", xG_sum)"
  },
  {
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，哪个俱乐部的红牌总数最多",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EPL_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nred_cards_by_club = df.groupby('Club')['Red_Cards'].sum()\nclub_with_most_red_cards = red_cards_by_club.idxmax()\nprint(f"在20-21赛季英超联赛中，红牌总数最多的俱乐部是：{club_with_most_red_cards}")"
 },
 {
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，为Chelsea俱乐部的球员出场数做一个折线图"，
  "output":"!pip install pandas\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EP_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nchelsea_players = df[df['Club'] == 'Chelsea']\nplt.plot(chelsea_players['Name'], chelsea_players['Matches'], marker='o')\nplt.xlabel('Player Name')\nplt.ylabel('Matches Played')\nplt.title('Chelsea Players Matches in EPL 20-21 Season')\nplt.xticks(rotation=90)\nplt.tight_layout()\nplt.show()"
  },
{
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，为Tottenham俱乐部的球员预期进球数做一个热图"，
  "output":"!pip install pandas\n!pip install seaborn\n!pip install xlrd\n!pip install matplotlib\nimport seabon as sns\nimport xlrd\nimport pandas as pd\nimport os\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EP_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ntottenham_players = df[df['Club'] == 'Tottenham']\nplt.figure(figsize=(10, 6))\nheatmap_data = tottenham_players.pivot('Name', 'Club', 'xG')\nsns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt=".2f", linewidths=.5)\nplt.title('Tottenham Players xG Heatmap')\nplt.show()"
  },
{
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，埃德森的传球成功率是多少",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EPL_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nederson_row = df[df['Name'] == 'Ederson']\nederson_pass_completion_rate = ederson_row['Perc_Passes_Completed'].values[0]\nprint(f"埃德森的传球成功率为: {ederson_pass_completion_rate}%")"
  },
{
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，出场时间最多的球员是哪个俱乐部的哪个球员",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EPL_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nmax_minutes_player = df[df['Mins'] == df['Mins'].max()]\nclub = max_minutes_player['Club'].values[0]\nplayer_name = max_minutes_player['Name'].values[0]\nprint(f"在20-21赛季英超联赛中，出场时间最多的球员是 {player_name}，他效力于 {club}。")"
  },
{
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，计算每个球员的场均出场时间，并将数据对应添加到最后一列",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EPL_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf['Avg_Mins'] = df['Mins'] / df['Matches']\ndf.to_excel('path_to_output_file.xlsx', index=False)"
  },
{
  "input":"EPL_20_21.xlsx中，在20-21赛季的英超联赛中，曼联队内球员的平均年龄是多少",
  "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'EPL_20_21.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nman_united_players = df[df['Club'] == 'Manchester United']\naverage_age = man_united_players['Age'].mean()\nprint(f"曼联队内球员的平均年龄是: {average_age:.2f} 岁")"
  },
{
  "input":"Automobile.xlsx中，燃油效率最高的汽车是哪一辆",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'Automobile.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nmax_mpg_car = df.loc[df['mpg'].idxmax()]\nprint("燃油效率最高的汽车是：")\nprint(max_mpg_car[['name', 'mpg']])"
   },
   {
  "input":"Automobile.xlsx中，产地为usa的车辆的平均重量是多少",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'Automobile.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nusa_cars = df[df['origin'] == 'usa']\naverage_weight = usa_cars['weight'].mean()\nprint(f"产地为USA的车辆的平均重量是: {average_weight}")"
   },
   {
  "input":"phones.xlsx中，Galaxy J4 Core对应品牌和操作系统是什么",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ngalaxy_j4_core_row = df[df['phone_name'] == 'Galaxy J4 Core']\nbrand = galaxy_j4_core_row['brand'].values[0]\nos = galaxy_j4_core_row['os'].values[0]\nprint(f'Galaxy J4 Core的品牌是：{brand}')\nprint(f'Galaxy J4 Core的操作系统是：{os}')"
   },
   {
  "input":"phones.xlsx中，计算不同电池类型的电池容量平均值",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\naverage_battery_capacity = df.groupby('battery_type')['battery'].mean()\nprint(average_battery_capacity)"
   },
   {
  "input":"phones.xlsx中，计算不同手机品牌的收集重量平均值，并按从大到小顺序为品牌排序",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\naverage_weight_by_brand = df.groupby('brand')['weight(g)'].mean()\nsorted_average_weight_by_brand = average_weight_by_brand.sort_values(ascending=False)\nprint(sorted_average_weight_by_brand)"
   },
   {
  "input":"phones.xlsx中，所有手机品牌中平均价格最贵的是哪个品牌",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\naverage_prices = df.groupby('brand')['price(USD)'].mean()\nmost_expensive_brand = average_prices.idxmax()\nprint(f"平均价格最贵的手机品牌是：{most_expensive_brand}")"
   },
   {
  "input":"phones.xlsx中，计算所有手机的价格与手机内存的比值，并将结果添加到表格最后一列",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf['price_ram_ratio'] = df['price(USD)'] / df['ram(GB)']\ndf.to_excel(file_path, index=False)"
   },
   {
  "input":"phones.xlsx中，摄像头有960fps功能的手机平均价格与摄像头有480fps功能手机平均价格的差值是多少",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\navg_price_960fps = df[df['video_960fps'] == True]['price(USD)'].mean()\navg_price_480fps = df[df['video_480fps'] == True]['price(USD)'].mean()\nprice_difference = avg_price_960fps - avg_price_480fps\nprint(f"摄像头有960fps功能的手机平均价格与有480fps功能的手机平均价格的差值是: {price_difference:.2f} USD")"
   },
   {
  "input":"phones.xlsx中，请计算不同手机屏幕分辨率对应的平均价格分别是多少，请将屏幕分辨率和其对应平均价格打印出来",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\naverage_prices = df.groupby('resolution')['price(USD)'].mean()\nprint("屏幕分辨率\t平均价格")\nprint("--------------------")\nfor resolution, avg_price in average_prices.items():\    print(f"{resolution}\t{avg_price:.2f}")"
   },
{
  "input":"phones.xlsx中，为不同品牌手机的平均价格做一个柱状图，横坐标为手机名称"，
  "output":"!pip install pandas\n!pip install seaborn\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\naverage_prices = df.groupby('brand')['price(USD)'].mean()\naverage_prices.plot(kind='bar', color='skyblue', edgecolor='black')\nplt.xlabel('手机品牌')\nplt.ylabel('平均价格 (USD)')\nplt.title('不同品牌手机的平均价格')\nplt.xticks(rotation=45, ha='right') \nplt.tight_layout() \nplt.show()"
  },
  {
  "input":"phones.xlsx中，为不同品牌手机的平均重量做一个折线图，横坐标为手机名称"，
  "output":"!pip install pandas\n!pip install seaborn\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\naverage_weight_by_brand = df.groupby('brand')['weight'].mean()\nplt.plot(average_weight_by_brand.index, average_weight_by_brand.values, marker='o')\nplt.title('Average Weight of Phones by Brand')\nplt.xlabel('Phone Brand')\nplt.ylabel('Average Weight')\nplt.xticks(rotation=45)\nplt.grid(True)\nplt.show()"
  } ,
  {
  "input":"phones.xlsx中，按照手机屏幕大小为不同品牌手机做热图"，
  "output":"!pip install pandas\n!pip install seaborn\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\n import seaborn as sns\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nheatmap_data = df.pivot_table(index='brand', columns='inches', aggfunc='size', fill_value=0)\nplt.figure(figsize=(12, 8))\nsns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='d', linewidths=.5)\nplt.title('手机屏幕大小和品牌热图')\nplt.xlabel('屏幕尺寸（inches）')\nplt.ylabel('手机品牌')\nplt.show()"
  },
  {
  "input":"phones.xlsx中，为不同品牌手机的平均存储容量做折线图"，
  "output":"!pip install pandas\n!pip install seaborn\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\naverage_storage_by_brand = df.groupby('brand')['storage(GB)'].mean()\nplt.figure(figsize=(10, 6))\naverage_storage_by_brand.plot(kind='line', marker='o')\nplt.title('Average Storage Capacity by Brand')\nplt.xlabel('Brand')\nplt.ylabel('Average Storage Capacity (GB)')\nplt.grid(True)\nplt.show()"
  },
  {
  "input":"phones.xlsx中，在品牌为Huawei的手机中按照手机内存的不同将其对应手机数量做饼图"，
  "output":"!pip install pandas\n!pip install seaborn\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nhuawei_phones = df[df['brand'] == 'Huawei']\nram_counts = huawei_phones['ram(GB)'].value_counts()\nplt.pie(ram_counts, labels=ram_counts.index, autopct='%1.1f%%', startangle=140)\nplt.title('Huawei Phones by RAM')\nplt.show()"
  },
  {
  "input":"phones.xlsx中,Xiaomi手机的平均价格是多少，最高价格是多少",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nxiaomi_df = df[df['brand'] == 'Xiaomi']\naverage_price = xiaomi_df['price(USD)'].mean()\nmax_price = xiaomi_df['price(USD)'].max()\nprint(f"Xiaomi手机的平均价格是: {average_price}")\nprint(f"Xiaomi手机的最高价格是: {max_price}")"
   },
   {
  "input":"phones.xlsx中,Huawei手机与Samsung手机的平均重量之差是多少",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'phones.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nhuawei_data = df[df['brand'] == 'Huawei']\nsamsung_data = df[df['brand'] == 'Samsung']\naverage_weight_huawei = huawei_data['weight(g)'].mean()\naverage_weight_samsung = samsung_data['weight(g)'].mean()\nweight_difference = average_weight_huawei - average_weight_samsung\nprint(f"Huawei手机与Samsung手机平均重量之差：{weight_difference} 克")"
   },
   {
  "input":"top250movies.xlsx中,2000年以前上映的电影有多少部",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'top250movies.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nmovies_before_2000 = df[df['year'] < 2000]\nnum_movies_before_2000 = len(movies_before_2000)\nprint(f"2000年以前上映的电影数量：{num_movies_before_2000}")"
   },
   {
  "input":"top250movies.xlsx中,预算最高的电影是哪一部，导演是谁",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'top250movies.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nmax_budget_movie = df[df['budget'] == df['budget'].max()]\nprint("预算最高的电影是：", max_budget_movie['name'].values[0])\nprint("导演是：", max_budget_movie['directors'].values[0])"
   },
   {
  "input":"top250movies.xlsx中,时长最短的电影是哪一部，导演是谁",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'top250movies.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf['run_time_minutes'] = df['run_time'].apply(lambda x: int(x.split('h')[0]) * 60 + int(x.split('m')[0].split()[-1]) if 'h' in x else int(x.split('m')[0]))\nshortest_movie_row = df[df['run_time_minutes'] == df['run_time_minutes'].min()]\nshortest_movie_name = shortest_movie_row['name'].values[0]\nshortest_movie_director = shortest_movie_row['directors'].values[0]\nprint(f"时长最短的电影是：{shortest_movie_name}")\nprint(f"导演是：{shortest_movie_director}")"
   },
   {
  "input":"top250movies.xlsx中,回报率最高的电影是哪一部，他的预算和票房是多少",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'top250movies.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf['return_on_investment'] = df['box_office'] / df['budget']\nmax_roi_movie = df.loc[df['return_on_investment'].idxmax()]\nprint("回报率最高的电影是：", max_roi_movie['name'])\nprint("预算是：", max_roi_movie['budget'])\nprint("票房是：", max_roi_movie['box_office'])\nprint("回报率是：", max_roi_movie['return_on_investment'])"
   },
   {
  "input":"top250movies.xlsx中,计算预算与电影评分的比值，并将其添加到表格最后一列",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'top250movies.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf['budget_rating_ratio'] = df['budget'] / df['rating']\ndf.to_excel(file_path, index=False)"
   },
   {
  "input":"top250movies.xlsx中,排名第25的电影是哪一部，他的评分是多少",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'top250movies.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nrank_25_movie = df.loc[24]\nmovie_name = rank_25_movie['name']\nmovie_rating = rank_25_movie['rating']\nprint(f"排名第25的电影是：{movie_name}")\nprint(f"电影评分是：{movie_rating}")"
   },
   {
  "input":"top250movies.xlsx中，按照不同电影类型所包含的电影数量作饼图"，
  "output":"!pip install pandas\n!pip install seaborn\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport seaborn as sns\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'top250movies.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ncertificate_counts = df['certificate'].value_counts()\nplt.figure(figsize=(8, 8))\nplt.pie(certificate_counts, labels=certificate_counts.index, autopct='%1.1f%%', startangle=140)\nplt.title('Distribution of Movies by Certificate')\nplt.show()"
   },
   {
  "input":"top250movies.xlsx中，按照年份为电影排序"，
  "output":"!pip install pandas\n!pip install seaborn\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport seaborn as sns\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'top250movies.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf_sorted = df.sort_values(by=['year', 'rank'])\nprint(df_sorted)"
  },
  {
  "input":"top250movies.xlsx中，请为2000年以后的电影预算做一个柱状图"，
  "output":"!pip install pandas\n!pip install seaborn\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport seaborn as sns\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'top250movies.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf_after_2000 = df[df['year'] >= 2000]\nplt.figure(figsize=(10, 6))\nplt.bar(df_after_2000['name'], df_after_2000['budget'], color='blue')\nplt.xlabel('电影名称')\nplt.ylabel('预算')\nplt.title('2000年以后电影的预算柱状图')\nplt.xticks(rotation=45, ha='right')\nplt.tight_layout()\nplt.show()"
  },
  {
  "input":"top250movies.xlsx中，请为2000年以前的电影预算做一个折线图"，
  "output":"!pip install pandas\n!pip install seaborn\n!pip install xlrd\n!pip install matplotlib\nimport xlrd\nimport pandas as pd\nimport os\nimport seaborn as sns\nimport matplotlib.pyplot as plt\nimport matplotlib\nmatplotlib.rc(\"font\",family='YouYuan')\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'top250movies.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf_before_2000 = df[df['year'] < 2000]\ndf_before_2000 = df_before_2000.sort_values(by='year')\nplt.figure(figsize=(10, 6))\nplt.plot(df_before_2000['year'], df_before_2000['budget'], marker='o', linestyle='-')\nplt.title('Movie Budgets Before 2000')\nplt.xlabel('Year')\nplt.ylabel('Budget')\nplt.grid(True)\nplt.show()"
  },
  {
  "input":"top250movies.xlsx中,有多少部类型为R的电影",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'top250movies.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nr_movies_count = df[df['certificate'] == 'R'].shape[0]\nprint(f"类型为 'R' 的电影数量：{r_movies_count}部")"
   },
   {
  "input":"top250movies.xlsx中,电影1917的导演是谁",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'top250movies.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nmovie_1917_director = df[df['name'] == '1917']['directors'].iloc[0]\nprint("电影《1917》的导演是:", movie_1917_director)"
   },
   {
  "input":"drinking_water_potability.xlsx中,可饮用水的平均ph值是多少",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'drinking_water_potability.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndf = df.dropna(subset=['ph'])\naverage_ph = df[df['Potability'] == 1]['ph'].mean()\nprint("可饮用水的平均ph值是:", average_ph)"
   },
   {
  "input":"drinking_water_potability.xlsx中,不可饮用水的平均硬度是多少",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'drinking_water_potability.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nnon_potable_water = df[df['Potability'] == 0]\naverage_hardness_non_potable = non_potable_water['Hardness'].mean()\nprint(f"不可饮用水的平均硬度是: {average_hardness_non_potable}")"
   },
   {
  "input":"drinking_water_potability.xlsx中,可饮用水中浊度最高是多少",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'drinking_water_potability.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\npotable_water_df = df[df['Potability'] == 1]\nmax_turbidity = potable_water_df['Turbidity'].max()\nprint(f"可饮用水中浊度的最大值是：{max_turbidity}")"
   },
   {
  "input":"drinking_water_potability.xlsx中,可饮用水的最低电导率是多少",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'drinking_water_potability.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\ndrinkable_water_data = df[df['Potability'] == 1]\nmin_conductivity = drinkable_water_data['Conductivity'].min()\nprint(f"可饮用水中电导率最低是: {min_conductivity}")"
   },
   {
  "input":"drinking_water_potability.xlsx中,第140行对应的水是否可饮用，它的ph值和硬度是多少",
   "output":"!pip install pandas\n!pip install xlrd\nimport xlrd\nimport pandas as pd\nimport os\nprint(os.getcwd())  # 获取当前工作目录\nnotebook_dir= os.getcwd()  # 获取 Jupyter Notebook 的当前工作目录\nexcel_file = os.path.join(notebook_dir, 'drinking_water_potability.xlsx')  # 拼接 Excel 文件的路径\ndf = pd.read_excel(excel_file)\nrow_140 = df.iloc[139]\nph_value = row_140['ph']\nhardness_value = row_140['Hardness']\npotability_value = row_140['Potability']\nconductivity_value = row_140['Conductivity']\nprint(f"水的pH值：{ph_value}")\nprint(f"水的硬度：{hardness_value}")\nprint(f"水的可饮用性：{potability_value}")\nprint(f"水的电导率：{conductivity_value}")"
   },
]
# Out:
#   Cell In[1], line 2
#     {
#     ^
# SyntaxError: '{' was never closed
